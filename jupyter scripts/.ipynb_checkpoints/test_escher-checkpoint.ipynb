# %%
import cobra
from openpyxl import load_workbook, styles, Workbook
import re
import escher
from escher import Builder

# Load model
model_path = "P://git/gem_sco/modelS.xml"
model = cobra.io.read_sbml_model(model_path)
# wb = load_workbook(xl_fn)

# %%
map_fn = "P://SCM/bigg_escher_map.json"
# map_fn = "P://git/gem_sco/modelS_map.json"

# %%
#model = cobra.io.json.from_json(escher.plots.model_json_for_name('e_coli_core'))
solution = model.optimize()

# %%
solution.x_dict.to_dict()
# Out:
# {'ACALD': 0.0,
#  'ACALDt': 0.0,
#  'ACKr': 0.0,
#  'ACONTa': 6.0072495753503423,
#  'ACONTb': 6.0072495753503423,
#  'ACt2r': 0.0,
#  'ADK1': 0.0,
#  'AKGDH': 5.0643756614821038,
#  'AKGt2r': 0.0,
#  'ALCD2x': 0.0,
#  'ATPM': 8.3900000000000006,
#  'ATPS4r': 45.51400977451754,
#  'BIOMASS_Ecoli_core_w_GAM': 0.87392150696843074,
#  'CO2t': -22.809833310204993,
#  'CS': 6.0072495753503423,
#  'CYTBD': 43.598985311997581,
#  'D_LACt2': 0.0,
#  'ENO': 14.716139568742843,
#  'ETOHt2r': 0.0,
#  'EX_ac_e': 0.0,
#  'EX_acald_e': 0.0,
#  'EX_akg_e': 0.0,
#  'EX_co2_e': 22.809833310204979,
#  'EX_etoh_e': 0.0,
#  'EX_for_e': 0.0,
#  'EX_fru_e': 0.0,
#  'EX_fum_e': 0.0,
#  'EX_glc__D_e': -10.0,
#  'EX_gln__L_e': 0.0,
#  'EX_glu__L_e': 0.0,
#  'EX_h2o_e': 29.175827135565815,
#  'EX_h_e': 17.530865429786687,
#  'EX_lac__D_e': 0.0,
#  'EX_mal__L_e': 0.0,
#  'EX_nh4_e': -4.7653191931974597,
#  'EX_o2_e': -21.799492655998794,
#  'EX_pi_e': -3.2148950476847533,
#  'EX_pyr_e': 0.0,
# ...

# %%
b = escher.Builder(map_json = map_fn, model = model,
                  reaction_data = solution.x_dict.to_dict(), highlight_missing = True)
                 # reaction_scale=[{'type': 'min', 'color': '#cccccc', 'size': 4},
                  #                 {'type': 'mean', 'color': '#0000dd', 'size': 20},
                   #                {'type': 'max', 'color': '#ff0000', 'size': 40}],)#, reaction_data = solution.x_dict)

# %%
b.display_in_notebook()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
b.display_in_browser()
# Out:
# Note: You must interrupt the kernel to end this command
#
# Serving to http://127.0.0.1:7655/
# [Ctrl-C to exit from terminal, or Ctrl-M i i to interrupt notebook kernel]
# 127.0.0.1 - - [11/Oct/2017 10:03:37] "GET / HTTP/1.1" 200 -

# %%
b.map_name = "e_coli_core.Core metabolism"
escher.list_available_maps()
# Out:
# [{'map_name': 'e_coli_core.Core metabolism', 'organism': 'Escherichia coli'},
#  {'map_name': 'iJO1366.Central metabolism', 'organism': 'Escherichia coli'},
#  {'map_name': 'iJO1366.Fatty acid beta-oxidation',
#   'organism': 'Escherichia coli'},
#  {'map_name': 'iJO1366.Fatty acid biosynthesis (saturated)',
#   'organism': 'Escherichia coli'},
#  {'map_name': 'iJO1366.Nucleotide and histidine biosynthesis',
#   'organism': 'Escherichia coli'},
#  {'map_name': 'iJO1366.Nucleotide metabolism', 'organism': 'Escherichia coli'},
#  {'map_name': 'RECON1.Amino acid metabolism (partial)',
#   'organism': 'Homo sapiens'},
#  {'map_name': 'RECON1.Carbohydrate metabolism', 'organism': 'Homo sapiens'},
#  {'map_name': 'RECON1.Glycolysis TCA PPP', 'organism': 'Homo sapiens'},
#  {'map_name': 'RECON1.Inositol retinol metabolism',
#   'organism': 'Homo sapiens'},
#  {'map_name': 'RECON1.Tryptophan metabolism', 'organism': 'Homo sapiens'},
#  {'map_name': 'iMM904.Central carbon metabolism',
# ...

# %%
model = cobra.io.json.from_json(escher.plots.model_json_for_name('e_coli_core'))
solution = model.optimize()
print('Growth rate: %.2f' % solution.f)
# Out:
# Growth rate: 0.87

# %%
import escher
import escher.urls
import cobra
import cobra.test
import json
import os
from IPython.display import HTML

# %%
b = escher.Builder(map_name='e_coli_core.Core metabolism',
                   reaction_data=solution.x_dict,
                   # change the default colors
                   reaction_scale=[{'type': 'min', 'color': '#cccccc', 'size': 4},
                                   {'type': 'mean', 'color': '#0000dd', 'size': 20},
                                   {'type': 'max', 'color': '#ff0000', 'size': 40}],
                   # only show the primary metabolites
                   hide_secondary_metabolites=True)
b.display_in_notebook(js_source='local')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-b4c89759c080> in <module>()
#       7                    # only show the primary metabolites
#       8                    hide_secondary_metabolites=True)
# ----> 9 b.display_in_notebook(js_source='local')
#
# C:\Users\snorres\AppData\Local\Continuum\Anaconda3\lib\site-packages\escher\plots.py in display_in_notebook(self, js_source, menu, scroll_behavior, minified_js, height, enable_editing)
#     655                               html_wrapper=False, enable_editing=enable_editing, enable_keys=False,
#     656                               minified_js=minified_js, fill_screen=False, height=height,
# --> 657                               never_ask_before_quit=True, ignore_bootstrap=True)
#     658         # import here, in case users don't have requirements installed
#     659         try:
#
# ...

# %%
import json
print(type(json_map))
map_d = json.loads(json_map)
# Out:
# <class 'str'>

# %%
map_d[1]["reactions"]
# Out:
# {'1576693': {'bigg_id': 'PGK',
#   'gene_reaction_rule': 'b2926',
#   'genes': [{'bigg_id': 'b2926', 'name': 'pgk'}],
#   'label_x': 1065.0,
#   'label_y': 2715.0,
#   'metabolites': [{'bigg_id': '3pg_c', 'coefficient': -1.0},
#    {'bigg_id': '13dpg_c', 'coefficient': 1.0},
#    {'bigg_id': 'atp_c', 'coefficient': -1.0},
#    {'bigg_id': 'adp_c', 'coefficient': 1.0}],
#   'name': 'Phosphoglycerate kinase',
#   'reversibility': True,
#   'segments': {'291': {'b1': None,
#     'b2': None,
#     'from_node_id': '1576835',
#     'to_node_id': '1576836'},
#    '292': {'b1': None,
#     'b2': None,
#     'from_node_id': '1576836',
#     'to_node_id': '1576834'},
#    '293': {'b1': {'x': 1055.0, 'y': 2822.4341649025255},
#     'b2': {'x': 1055.0, 'y': 2789.230249470758},
#     'from_node_id': '1576485',
#     'to_node_id': '1576835'},
#    '294': {'b1': {'x': 1055.0, 'y': 2825.0},
#     'b2': {'x': 1055.0, 'y': 2790.0},
#     'from_node_id': '1576486',
#     'to_node_id': '1576835'},
# ...

# %% [markdown]
# cobra.flux_analysis.double_gene_deletion??

# %%
d_ess = cobra.flux_analysis.double_reaction_deletion(model, reaction_list1 = model.reactions[:3], return_frame = True)

# %%
d_ess
# Out:
# {'data': array([[ 0.07539807,  0.07539807,  0.07539807,  0.07539807,  0.07539807,
#           0.07539807,  0.07539807,  0.07539807,  0.07539807,  0.07539807],
#         [ 0.07539807,  0.07539807,  0.07539807,  0.07539807,  0.07539807,
#           0.07539807,  0.07539807,  0.07539807,  0.07539807,  0.07539807],
#         [ 0.07539807,  0.07539807,  0.07539807,  0.07539807,  0.07539807,
#           0.07539807,  0.07539807,  0.07539807,  0.07539807,  0.07539807],
#         [ 0.07539807,  0.07539807,  0.07539807,  0.07539807,  0.07539807,
#           0.07539807,  0.07539807,  0.07539807,  0.07539807,  0.07539807],
#         [ 0.07539807,  0.07539807,  0.07539807,  0.07539807,  0.07539807,
#           0.07539807,  0.07539807,  0.07539807,  0.07539807,  0.07539807],
#         [ 0.07539807,  0.07539807,  0.07539807,  0.07539807,  0.07539807,
#           0.07539807,  0.07539807,  0.07539807,  0.07539807,  0.07539807],
# ...

# %%
cobra.flux_analysis.double_reaction_deletion?
