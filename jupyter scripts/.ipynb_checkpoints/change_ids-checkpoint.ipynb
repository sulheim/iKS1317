# %%
import cobra
from openpyxl import load_workbook, styles, Workbook
import re

# %%
# Load model
model_path = "P://git/gem_sco/modelS.xml"
xl_fn = "P://git/gem_sco/modelS.xlsx"
model = cobra.io.read_sbml_model(model_path)
wb = load_workbook(xl_fn)

# %%
# Change reaction ids

# %%
# Reactions
sheet = wb.get_sheet_by_name("Reactions")
count = 0
for i in range(2, sheet.max_row+1):
    old_id = sheet.cell(row = i, column = 1).value
    if not old_id:
        continue
    
    # Add extra underscore
    new_id = re.sub("EX_[a-zA-Z]+_[DL]$", insert_underscore_r, old_id)
    
    # Add "_e" to end
    if new_id[:3] == "EX_":
        if new_id[-2:] != "_e":
            new_id = new_id +"_e"
            
    if new_id[:3] == "DM_":
        r = model.reactions.get_by_id(old_id)
        m_id = [x.id for x in r.metabolites][0]
        new_id = "DM_" + m_id
            
    if new_id != old_id:
        r = model.reactions.get_by_id(old_id)
        r.id = new_id
        sheet.cell(row = i, column = 1).value = new_id
        print(old_id, new_id, [x.id for x in r.metabolites])
        count += 1
print("Changed {0} reaction ids".format(count))
# Out:
# DM_2HYMEPH DM_2hymeph_c ['2hymeph_c']
# DM_4CRSOL DM_4crsol_c ['4crsol_c']
# DM_5DRIB DM_5drib_c ['5drib_c']
# DM_AACALD DM_aacald_c ['aacald_c']
# DM_ACONM DM_aconm_c ['aconm_c']
# DM_ACT DM_ACT_c ['ACT_c']
# DM_AMOB DM_amob_c ['amob_c']
# DM_DALUA DM_dalua_c ['dalua_c']
# DM_ECTOINE DM_ectoine__L_c ['ectoine__L_c']
# DM_GERMA DM_germicidinA_c ['germicidinA_c']
# DM_GERMB DM_germicidinB_c ['germicidinB_c']
# DM_GERMC DM_germicidinC_c ['germicidinC_c']
# DM_GERMD DM_germicidinD_c ['germicidinD_c']
# DM_MSH DM_msh_c ['msh_c']
# DM_RED DM_RED_c ['RED_c']
# EX_14glucan EX_14glucan_e ['14glucan_e']
# EX_15dap EX_15dap_e ['15dap_e']
# EX_1Dgali EX_1Dgali_e ['1Dgali_e']
# EX_23camp EX_23camp_e ['23camp_e']
# EX_23ccmp EX_23ccmp_e ['23ccmp_e']
# EX_23cgmp EX_23cgmp_e ['23cgmp_e']
# EX_23cump EX_23cump_e ['23cump_e']
# EX_26dap_M EX_26dap_M_e ['26dap_M_e']
# EX_2ddglcn EX_2ddglcn_e ['2ddglcn_e']
# EX_3amp EX_3amp_e ['3amp_e']
# EX_3cmp EX_3cmp_e ['3cmp_e']
# EX_3gmp EX_3gmp_e ['3gmp_e']
# EX_3ump EX_3ump_e ['3ump_e']
# EX_4abut EX_4abut_e ['4abut_e']
# EX_5dglcn EX_5dglcn_e ['5dglcn_e']
# EX_5mtr EX_5mtr_e ['5mtr_e']
# EX_abt_D EX_abt__D_e ['abt__D_e']
# EX_ac EX_ac_e ['ac_e']
# EX_acald EX_acald_e ['acald_e']
# EX_acgam EX_acgam_e ['acgam_e']
# EX_acser EX_acser_e ['acser_e']
# EX_ade EX_ade_e ['ade_e']
# EX_adn EX_adn_e ['adn_e']
# EX_agm EX_agm_e ['agm_e']
# EX_akg EX_akg_e ['akg_e']
# EX_alaala EX_alaala_e ['alaala_e']
# EX_ala_B EX_ala_B_e ['ala_B_e']
# EX_ala_D EX_ala__D_e ['ala__D_e']
# EX_ala_L EX_ala__L_e ['ala__L_e']
# EX_alltn EX_alltn_e ['alltn_e']
# EX_amp EX_amp_e ['amp_e']
# EX_arab_L EX_arab__L_e ['arab__L_e']
# EX_arg_L EX_arg__L_e ['arg__L_e']
# EX_asn_L EX_asn__L_e ['asn__L_e']
# EX_aso3 EX_aso3_e ['aso3_e']
# EX_asp_L EX_asp__L_e ['asp__L_e']
# EX_bhb EX_bhb_e ['bhb_e']
# EX_btn EX_btn_e ['btn_e']
# EX_ca2 EX_ca2_e ['ca2_e']
# EX_cbi EX_cbi_e ['cbi_e']
# EX_cbl1 EX_cbl1_e ['cbl1_e']
# EX_cd2 EX_cd2_e ['cd2_e']
# EX_CDA EX_CDA_e ['CDA_e']
# EX_celb EX_celb_e ['celb_e']
# EX_chol EX_chol_e ['chol_e']
# EX_chtbs EX_chtbs_e ['chtbs_e']
# EX_cit EX_cit_e ['cit_e']
# EX_cl EX_cl_e ['cl_e']
# EX_cmp EX_cmp_e ['cmp_e']
# EX_co2 EX_co2_e ['co2_e']
# EX_cobalt2 EX_cobalt2_e ['cobalt2_e']
# EX_coelichelin EX_coelichelin_e ['coelichelin_e']
# EX_csn EX_csn_e ['csn_e']
# EX_cu EX_cu_e ['cu_e']
# EX_cu2 EX_cu2_e ['cu2_e']
# EX_cys_L EX_cys__L_e ['cys__L_e']
# EX_cytd EX_cytd_e ['cytd_e']
# EX_dad_2 EX_dad_2_e ['dad_2_e']
# EX_damp EX_damp_e ['damp_e']
# EX_dcmp EX_dcmp_e ['dcmp_e']
# EX_dcyt EX_dcyt_e ['dcyt_e']
# EX_desferrioxamB EX_desferrioxamB_e ['desferrioxamB_e']
# EX_desferrioxamE EX_desferrioxamE_e ['desferrioxamE_e']
# EX_dgmp EX_dgmp_e ['dgmp_e']
# EX_dgsn EX_dgsn_e ['dgsn_e']
# EX_dha EX_dha_e ['dha_e']
# EX_dimp EX_dimp_e ['dimp_e']
# EX_din EX_din_e ['din_e']
# EX_drib EX_drib_e ['drib_e']
# EX_dtmp EX_dtmp_e ['dtmp_e']
# EX_dump EX_dump_e ['dump_e']
# EX_duri EX_duri_e ['duri_e']
# EX_epm EX_epm_e ['epm_e']
# EX_etha EX_etha_e ['etha_e']
# EX_etoh EX_etoh_e ['etoh_e']
# EX_fald EX_fald_e ['fald_e']
# EX_fe2 EX_fe2_e ['fe2_e']
# EX_fe3 EX_fe3_e ['fe3_e']
# EX_ferricoelichelin EX_ferricoelichelin_e ['ferricoelichelin_e']
# EX_ferrioxamB EX_ferrioxamB_e ['ferrioxamB_e']
# EX_ferrioxamE EX_ferrioxamE_e ['ferrioxamE_e']
# EX_for EX_for_e ['for_e']
# EX_fru EX_fru_e ['fru_e']
# EX_fum EX_fum_e ['fum_e']
# EX_g3pc EX_g3pc_e ['g3pc_e']
# EX_g3pe EX_g3pe_e ['g3pe_e']
# EX_g3pg EX_g3pg_e ['g3pg_e']
# EX_g3pi EX_g3pi_e ['g3pi_e']
# EX_g3ps EX_g3ps_e ['g3ps_e']
# EX_gACT EX_gACT_e ['gACT_e']
# EX_gal EX_gal_e ['gal_e']
# EX_galctn_D EX_galctn__D_e ['galctn__D_e']
# EX_ggl EX_ggl_e ['ggl_e']
# EX_glc EX_glc_e ['glc__D_e']
# EX_glcn EX_glcn_e ['glcn_e']
# EX_glcr EX_glcr_e ['glcr_e']
# EX_gln_L EX_gln__L_e ['gln__L_e']
# EX_glu_L EX_glu__L_e ['glu__L_e']
# EX_gly EX_gly_e ['gly_e']
# EX_glyald EX_glyald_e ['glyald_e']
# EX_glyb EX_glyb_e ['glyb_e']
# EX_glyc EX_glyc_e ['glyc_e']
# EX_glyc3p EX_glyc3p_e ['glyc3p_e']
# EX_glyclt EX_glyclt_e ['glyclt_e']
# EX_glyc_R EX_glyc_R_e ['glyc_R_e']
# EX_gmp EX_gmp_e ['gmp_e']
# EX_gsn EX_gsn_e ['gsn_e']
# EX_gua EX_gua_e ['gua_e']
# EX_h EX_h_e ['h_e']
# EX_h2o EX_h2o_e ['h2o_e']
# EX_h2o2 EX_h2o2_e ['h2o2_e']
# EX_h2s EX_h2s_e ['h2s_e']
# EX_his_L EX_his__L_e ['his__L_e']
# EX_hom_L EX_hom__L_e ['hom__L_e']
# EX_idon_L EX_idon__L_e ['idon__L_e']
# EX_ile_L EX_ile__L_e ['ile__L_e']
# EX_imp EX_imp_e ['imp_e']
# EX_indole EX_indole_e ['indole_e']
# EX_inost EX_inost_e ['inost_e']
# EX_ins EX_ins_e ['ins_e']
# EX_k EX_k_e ['k_e']
# EX_lac_D EX_lac__D_e ['lac__D_e']
# EX_lac_L EX_lac__L_e ['lac__L_e']
# EX_LalaDglu EX_LalaDglu_e ['LalaDglu_e']
# EX_lcts EX_lcts_e ['lcts_e']
# EX_leu_L EX_leu__L_e ['leu__L_e']
# EX_lipoate EX_lipoate_e ['lipoate_e']
# EX_lys_L EX_lys__L_e ['lys__L_e']
# EX_lyx_L EX_lyx__L_e ['lyx__L_e']
# EX_mal_L EX_mal__L_e ['mal__L_e']
# EX_malt EX_malt_e ['malt_e']
# EX_malthp EX_malthp_e ['malthp_e']
# EX_malthx EX_malthx_e ['malthx_e']
# EX_maltpt EX_maltpt_e ['maltpt_e']
# EX_malttr EX_malttr_e ['malttr_e']
# EX_maltttr EX_maltttr_e ['maltttr_e']
# EX_man EX_man_e ['man_e']
# EX_melib EX_melib_e ['melib_e']
# EX_melt EX_melt_e ['melt_e']
# EX_meoh EX_meoh_e ['meoh_e']
# EX_met_L EX_met__L_e ['met__L_e']
# EX_mg2 EX_mg2_e ['mg2_e']
# EX_mn2 EX_mn2_e ['mn2_e']
# EX_mnl EX_mnl_e ['mnl_e']
# EX_mobd EX_mobd_e ['mobd_e']
# EX_n2o EX_n2o_e ['n2o_e']
# EX_na1 EX_na1_e ['na1_e']
# EX_nac EX_nac_e ['nac_e']
# EX_nh4 EX_nh4_e ['nh4_e']
# EX_ni2 EX_ni2_e ['ni2_e']
# EX_nmn EX_nmn_e ['nmn_e']
# EX_no EX_no_e ['no_e']
# EX_no2 EX_no2_e ['no2_e']
# EX_no3 EX_no3_e ['no3_e']
# EX_o2 EX_o2_e ['o2_e']
# EX_orn EX_orn_e ['orn_e']
# EX_orot EX_orot_e ['orot_e']
# EX_pacald EX_pacald_e ['pacald_e']
# EX_phe_L EX_phe__L_e ['phe__L_e']
# EX_pi EX_pi_e ['pi_e']
# EX_pnto_R EX_pnto_R_e ['pnto_R_e']
# EX_ppa EX_ppa_e ['ppa_e']
# EX_pro_L EX_pro__L_e ['pro__L_e']
# EX_ptrc EX_ptrc_e ['ptrc_e']
# EX_pydam EX_pydam_e ['pydam_e']
# EX_pydx EX_pydx_e ['pydx_e']
# EX_pydxn EX_pydxn_e ['pydxn_e']
# EX_pyr EX_pyr_e ['pyr_e']
# EX_raffin EX_raffin_e ['raffin_e']
# EX_rib_D EX_rib__D_e ['rib__D_e']
# EX_rmn EX_rmn_e ['rmn_e']
# EX_salcn EX_salcn_e ['salcn_e']
# EX_sbt_D EX_sbt__D_e ['sbt__D_e']
# EX_ser_L EX_ser__L_e ['ser__L_e']
# EX_skm EX_skm_e ['skm_e']
# EX_so4 EX_so4_e ['so4_e']
# EX_spmd EX_spmd_e ['spmd_e']
# EX_succ EX_succ_e ['succ_e']
# EX_tartr_D EX_tartr__D_e ['tartr__D_e']
# EX_taur EX_taur_e ['taur_e']
# EX_thm EX_thm_e ['thm_e']
# EX_thr_L EX_thr__L_e ['thr__L_e']
# EX_thym EX_thym_e ['thym_e']
# EX_thymd EX_thymd_e ['thymd_e']
# EX_tre EX_tre_e ['tre_e']
# EX_trp_L EX_trp__L_e ['trp__L_e']
# EX_tungs EX_tungs_e ['tungs_e']
# EX_tyr_L EX_tyr__L_e ['tyr__L_e']
# EX_ump EX_ump_e ['ump_e']
# EX_ura EX_ura_e ['ura_e']
# EX_urea EX_urea_e ['urea_e']
# EX_uri EX_uri_e ['uri_e']
# EX_val_L EX_val__L_e ['val__L_e']
# EX_vanlt EX_vanlt_e ['vanlt_e']
# EX_xan EX_xan_e ['xan_e']
# EX_xmp EX_xmp_e ['xmp_e']
# EX_xtsn EX_xtsn_e ['xtsn_e']
# EX_xyl_D EX_xyl__D_e ['xyl__D_e']
# EX_xylt EX_xylt_e ['xylt_e']
# EX_zn2 EX_zn2_e ['zn2_e']
# EX_sucr EX_sucr_e ['sucr_e']
# Changed 216 reaction ids

# %%
r = model.reactions.EX_ala_D
r.metabolites
# Out:
# {<Metabolite ala_D_e at 0x97a416a128>: -1.0}

# %%
def insert_underscore_r(match):
    substring = match.group(0)
    string_list = substring.rsplit("_", 1)
    return string_list[0] + '__' + string_list[1]

def insert_underscore_m(match):
    substring = match.group(0)
    return substring[0] + '_' + substring[1:]

# %%
# Metabolites


sheet = wb.get_sheet_by_name("Metabolites")
count = 0
for i in range(2, sheet.max_row+1):
    old_id = sheet.cell(row = i, column = 1).value
    if not old_id:
        continue
    # Add extra underscore
    new_id = re.sub("[a-zA-Z]_[DL]_[ce]$", insert_underscore_m, old_id)
    if new_id != old_id:
        model.metabolites.get_by_id(old_id).id = new_id
        sheet.cell(row = i, column = 1).value = new_id
        print(old_id, new_id)
        count += 1
        
    

print("Changed {0} metabolite ids".format(count))
# Out:
# abt_D_c abt__D_c
# acglc_D_c acglc__D_c
# ala_D_c ala__D_c
# ala_L_c ala__L_c
# arab_L_c arab__L_c
# arg_L_c arg__L_c
# asn_L_c asn__L_c
# asp_L_c asp__L_c
# athr_L_c athr__L_c
# citr_L_c citr__L_c
# cys_L_c cys__L_c
# cyst_L_c cyst__L_c
# ectoine_L_c ectoine__L_c
# galctn_D_c galctn__D_c
# glc_D_c glc__D_c
# gln_L_c gln__L_c
# glu_D_c glu__D_c
# glu_L_c glu__L_c
# hcys_L_c hcys__L_c
# his_L_c his__L_c
# hom_L_c hom__L_c
# idon_L_c idon__L_c
# ile_L_c ile__L_c
# lac_D_c lac__D_c
# lac_L_c lac__L_c
# lald_L_c lald__L_c
# leu_L_c leu__L_c
# lys_L_c lys__L_c
# lyx_L_c lyx__L_c
# mal_L_c mal__L_c
# met_L_c met__L_c
# metsox_R_L_c metsox_R__L_c
# metsox_S_L_c metsox_S__L_c
# mi1p_D_c mi1p__D_c
# mi1p_L_c mi1p__L_c
# phe_L_c phe__L_c
# pro_L_c pro__L_c
# pser_L_c pser__L_c
# rbl_L_c rbl__L_c
# rib_D_c rib__D_c
# ru5p_D_c ru5p__D_c
# ru5p_L_c ru5p__L_c
# sbt_D_c sbt__D_c
# ser_L_c ser__L_c
# tag6p_D_c tag6p__D_c
# tagdp_D_c tagdp__D_c
# tartr_D_c tartr__D_c
# thr_L_c thr__L_c
# trp_L_c trp__L_c
# tyr_L_c tyr__L_c
# val_L_c val__L_c
# xu5p_D_c xu5p__D_c
# xu5p_L_c xu5p__L_c
# xyl_D_c xyl__D_c
# xylu_D_c xylu__D_c
# xylu_L_c xylu__L_c
# abt_D_e abt__D_e
# ala_D_e ala__D_e
# ala_L_e ala__L_e
# arab_L_e arab__L_e
# arg_L_e arg__L_e
# asn_L_e asn__L_e
# asp_L_e asp__L_e
# cys_L_e cys__L_e
# galctn_D_e galctn__D_e
# glc_D_e glc__D_e
# gln_L_e gln__L_e
# glu_L_e glu__L_e
# his_L_e his__L_e
# hom_L_e hom__L_e
# idon_L_e idon__L_e
# ile_L_e ile__L_e
# lac_D_e lac__D_e
# lac_L_e lac__L_e
# leu_L_e leu__L_e
# lys_L_e lys__L_e
# lyx_L_e lyx__L_e
# mal_L_e mal__L_e
# met_L_e met__L_e
# phe_L_e phe__L_e
# pro_L_e pro__L_e
# rib_D_e rib__D_e
# sbt_D_e sbt__D_e
# ser_L_e ser__L_e
# tartr_D_e tartr__D_e
# thr_L_e thr__L_e
# trp_L_e trp__L_e
# tyr_L_e tyr__L_e
# val_L_e val__L_e
# xyl_D_e xyl__D_e
# Changed 90 metabolite ids

# %%
# Save model
cobra.io.write_sbml_model(model, model_path, use_fbc_package = True)
wb.save(xl_fn)

# %%
a = "EX_ala_L"
m = re.sub("[a-zA-Z]_[DL]$", insert_underscore, a)
m
# Out:
# 'EX_ala__L'
